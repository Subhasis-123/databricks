# %%
# %python
print("dev to qa")
print("just to test")
print("subhasis move to qa")

# %%
df = spark.read.option("header", True).csv("/Volumes/workspace/default/test/Book1.csv")
df.show(5)

# %%
grouped_df = df.groupBy("category").agg({"value": "sum"})
grouped_df.show()

# %%
result = grouped_df.collect()
print(result)

# %%
df.count()  # Job 1
grouped_df.collect()  # Job 2
grouped_df.write.mode("overwrite").csv("/Volumes/workspace/default/test/output")  # Job 3
grouped_df.explain(True)
